# %% [markdown]
# # **** IPL DATASET ANALYSIS  ****

# %% [markdown]
# <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/ipl1.jpg?raw=true' width=300 height=300 >

# %%
# Importing the Useful Libraries

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# %%
matches1=pd.read_csv('Matches IPL 2008-2019.csv')
matches1
# Out:
#         id  season           city        date                  team1  \
# 0       60    2008      Bangalore  18-04-2008  Kolkata Knight Riders
# 1       61    2008     Chandigarh  19-04-2008    Chennai Super Kings
# 2       62    2008          Delhi  19-04-2008       Rajasthan Royals
# 3       63    2008         Mumbai  20-04-2008         Mumbai Indians
# 4       64    2008        Kolkata  20-04-2008        Deccan Chargers
# ..     ...     ...            ...         ...                    ...
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
matches2=pd.read_csv('Matches IPL 2020.csv')
matches2
# Out:
#          id  season         city        date team1 team2 toss_winner  \
# 0   1216492    2020    Abu Dhabi  09/19/2020    MI   CSK         CSK
# 1   1216493    2020  Dubai (DSC)  09/20/2020    DC  KXIP        KXIP
# 2   1216534    2020  Dubai (DSC)  09/21/2020   SRH   RCB         SRH
# 3   1216496    2020      Sharjah  09/22/2020    RR   CSK         CSK
# 4   1216508    2020    Abu Dhabi  09/23/2020   KKR    MI         KKR
# 5   1216510    2020  Dubai (DSC)  09/24/2020  KXIP   RCB         RCB
# 6   1216539    2020  Dubai (DSC)  09/25/2020   CSK    DC         CSK
# 7   1216545    2020    Abu Dhabi  09/26/2020   KKR   SRH         SRH
# 8   1216527    2020      Sharjah  09/27/2020    RR  KXIP          RR
# 9   1216547    2020  Dubai (DSC)  09/28/2020   RCB    MI          MI
# 10  1216532    2020    Abu Dhabi  09/29/2020    DC   SRH          DC
# 11  1216504    2020  Dubai (DSC)  09/30/2020    RR   KKR          RR
# 12  1216503    2020    Abu Dhabi    10-01-20  KXIP    MI        KXIP
# ...

# %%
matches = pd.concat([matches1,matches2], ignore_index = True)
matches
# Out:
#           id  season         city        date                  team1  \
# 0         60    2008    Bangalore  18-04-2008  Kolkata Knight Riders
# 1         61    2008   Chandigarh  19-04-2008    Chennai Super Kings
# 2         62    2008        Delhi  19-04-2008       Rajasthan Royals
# 3         63    2008       Mumbai  20-04-2008         Mumbai Indians
# 4         64    2008      Kolkata  20-04-2008        Deccan Chargers
# ..       ...     ...          ...         ...                    ...
# 811  1216495    2020      Sharjah    11-03-20                    SRH
# 812  1237177    2020  Dubai (DSC)    11-05-20                     DC
# 813  1237178    2020    Abu Dhabi    11-06-20                    RCB
# 814  1237180    2020    Abu Dhabi    11-08-20                     DC
# 815  1237181    2020  Dubai (DSC)    11-10-20                     DC
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# <pre>
# TEAM NAMES With Short Names
# MI: 'Mumbai Indians',
# KKR: 'Kolkata Knight Riders',
# CSK: 'Chennai Super Kings',
# RCB: 'Royal Challengers Bangalore',
# KXIP: 'Kings XI Punjab',
# RR: 'Rajasthan Royals',
# DD: 'Delhi Daredevils',
# SRH: 'Sunrisers Hyderabad',
# DC: 'Deccan Chargers',
# PWI: 'Pune Warriors',
# GL: 'Gujarat Lions',
# DCa: 'Delhi Capitals',
# KTK: 'Kochi Tuskers Kerala',
# RPS: 'Rising Pune Supergiants'
# </pre>

# %% [markdown]
# <pre><B>DESCRIPTION OF DATA</b>
# Season: Year in which ipl held
# city: City where matches were held
# date: Date on which matches were held
# team1: Name of First Team
# team2: Name of Second Team
# toss_winner: Team winning the toss
# toss_decision: Team's decision after winning toss
#                 bat
#                 or
#                 field
# result: normal
#         or
#         tie
#         or
#         no result
# dl_applied: Duckworth Lewis Rule applied  or not
#             0 for no,
#             1 for yes
# winner: Winning Team
# win_by_runs: Team Winning by how much runs, 0 in case of winning by wickets
# win_by_wickets: Team Winning by how much wickets, 0 in case of winning by runs
# player_of_match: Player of tha match
# venue: Stadium name where match was held
# umpire1: Name of first Umpire
# umpire2: Name of Second Umpire
# </pre>

# %%
matches.season.value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2020    60
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   season           816 non-null    int64
#  2   city             809 non-null    object
#  3   date             816 non-null    object
#  4   team1            816 non-null    object
#  5   team2            816 non-null    object
#  6   toss_winner      816 non-null    object
#  7   toss_decision    816 non-null    object
#  8   result           816 non-null    object
#  9   dl_applied       816 non-null    int64
#  10  winner           812 non-null    object
#  11  win_by_runs      816 non-null    int64
#  12  win_by_wickets   816 non-null    int64
#  13  player_of_match  812 non-null    object
#  14  venue            816 non-null    object
#  15  umpire1          814 non-null    object
#  16  umpire2          814 non-null    object
# ...

# %% [markdown]
# #### Changing team names as there are double team name with short forms

# %%
a=matches['toss_winner'].value_counts().index.tolist()
a
# Out:
# ['Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Chennai Super Kings',
#  'Royal Challengers Bangalore',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Gujarat Lions',
#  'SRH',
#  'Delhi Capitals',
#  'DC',
#  'Kochi Tuskers Kerala',
#  'CSK',
#  'MI',
#  'Rising Pune Supergiants',
#  'RR',
#  'Rising Pune Supergiant',
#  'RCB',
#  'KKR',
#  'KXIP']

# %% [markdown]
# <pre>if we see "a",  it will look like
# ['Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Chennai Super Kings',
#  'Kings XI Punjab',
#  'Royal Challengers Bangalore',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Sunrisers Hyderabad',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Gujarat Lions',
#  'SRH',
#  'DC',
#  'Delhi Capitals',
#  'MI',
#  'CSK',
#  'Kochi Tuskers Kerala',
#  'RR',
#  'Rising Pune Supergiants',
#  'KKR',
#  'RCB',
#  'Rising Pune Supergiant',
#  'KXIP']

# %% [markdown]
# <pre><b>So</b> basically Srh and sunrisers hyderabad are same,
# Dc and delhi capitals are same and many others

# %%
b=["MI","KKR","CSK","RCB","KXIP","DD","RR","SRH","DC","PWI","GL","DCa","KTK","RPS","RPS"]

# %% [markdown]
# So We change it accordingly

# %%
matches=matches.replace(a[0:11],b[0:11])

# %%
a=matches['toss_winner'].value_counts().index.tolist()
a
# Out:
# ['MI',
#  'KKR',
#  'CSK',
#  'RCB',
#  'RR',
#  'KXIP',
#  'DD',
#  'SRH',
#  'DC',
#  'PWI',
#  'GL',
#  'Delhi Capitals',
#  'Kochi Tuskers Kerala',
#  'Rising Pune Supergiants',
#  'Rising Pune Supergiant']

# %%
matches=matches.replace(a[12:],b[12:])
matches=matches.replace(a[11:12],b[11:12])

# %%
matches['toss_winner'].value_counts().index.tolist()
# Out:
# ['MI',
#  'KKR',
#  'CSK',
#  'RCB',
#  'RR',
#  'KXIP',
#  'DD',
#  'SRH',
#  'DC',
#  'PWI',
#  'GL',
#  'RPS',
#  'DCa',
#  'KTK']

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# # Matches played in Season wise

# %%
count_match_seasonwise=matches["season"].value_counts()
count_match_seasonwise
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2020    60
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
season_list=matches["season"].value_counts().index.tolist()
season_list
# Out:
# [2013, 2012, 2011, 2020, 2019, 2018, 2016, 2014, 2010, 2017, 2015, 2008, 2009]

# %%
plt.figure(figsize=(10,5))
plt.bar(season_list,count_match_seasonwise)
plt.xticks(rotation=45)

plt.xlabel('Season',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Season Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Season Wise STATISTICS')

# %%
season = matches['season'].value_counts()
plt.figure(figsize=(10,7), facecolor='#FFDAB9')
plt.bar(x=season.index, height=season.values)
plt.title('Number of Matches in Each Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches Played')
plt.show()
season = pd.DataFrame(season)
season.T
# Out:
#         2013  2012  2011  2020  2019  2018  2016  2014  2010  2017  2015  \
# season    76    74    73    60    60    60    60    60    60    59    59
#
#         2008  2009
# season    58    57

# %% [markdown]
# * As one can see maximum number of matches played in 2011, 2012, 2013. This is the time was in very high demand.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# # Matches Played on different venues ? select top 10

# %%
count_match_venues=matches["venue"].value_counts().head(10)
count_match_venues
# Out:
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         73
# Feroz Shah Kotla                              67
# Rajiv Gandhi International Stadium, Uppal     56
# MA Chidambaram Stadium, Chepauk               49
# Sawai Mansingh Stadium                        47
# Punjab Cricket Association Stadium, Mohali    35
# Dubai International Cricket Stadium           33
# Sheikh Zayed Stadium, Abu Dhabi               22
# Name: venue, dtype: int64

# %%
matches["venue"].value_counts()
# Out:
# Eden Gardens                                            77
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium, Abu Dhabi                         22
# Maharashtra Cricket Association Stadium                 21
# Sharjah Cricket Stadium                                 18
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# ...

# %%
venue_names=matches["venue"].value_counts().head(10).index.tolist()
venue_names
# Out:
# ['Eden Gardens',
#  'Wankhede Stadium',
#  'M Chinnaswamy Stadium',
#  'Feroz Shah Kotla',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'MA Chidambaram Stadium, Chepauk',
#  'Sawai Mansingh Stadium',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Dubai International Cricket Stadium',
#  'Sheikh Zayed Stadium, Abu Dhabi']

# %%
plt.figure(figsize=(10,5))
plt.bar(venue_names,count_match_venues)
plt.xticks(rotation=90)

plt.xlabel('Venue',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Venue Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Venue Wise STATISTICS')

# %%
plt.figure(figsize=(10,5))
plt.plot(venue_names,count_match_venues)
plt.xticks(rotation=90)


plt.xlabel('Venues',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Venue Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Venue Wise STATISTICS')

# %%
venue =matches['venue'].value_counts()[:20]
plt.figure(figsize=(15,7), facecolor='#00ff7F')
plt.bar(x=venue.index, height=venue.values)
plt.title('Number of Matches in each Venue')
plt.xlabel('Stadium')
plt.ylabel('Number of matches played')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * The maximum matches played on M Chinnaswamy stadium. <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/rcb_stadium.jpg?raw=true' width=400 height=300><br> * Other favuorite stadiums are Eden Gardens(Lords of India :p) , Feroz Shah Kotla, Wankhede stadium.

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# # Number of matches played by each team.

# %%
temp_df = pd.concat([matches['team1'], matches['team2']])

# %%
temp_df = temp_df.value_counts()

# %%
temp_df
# Out:
# MI      203
# RCB     195
# KKR     192
# KXIP    190
# CSK     178
# DD      161
# RR      161
# SRH     124
# DC       92
# PWI      46
# RPS      30
# GL       30
# DCa      16
# KTK      14
# dtype: int64

# %%
plt.figure(figsize=(15,7), facecolor='#FFDAB9')
plt.bar(x=temp_df.index, height=temp_df.values,)
plt.title('Number of Matches played by each team')
plt.xlabel('Team')
plt.ylabel('Number of Matches')
plt.xticks(rotation=90)

for i,v in enumerate(temp_df.values):
    plt.text(x=i, y=v+2, s=v)
    
plt.show()

# %% [markdown]
# * Maximum number of matches played by Mumbai Indians, RCB, KKR.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # Number of Total Matches wins per Team.

# %%
winner = matches['winner'].value_counts()
winner = pd.DataFrame(winner)
winner.columns = ['Total Matches']
winner.index.name = 'Team'

winner.plot(kind='bar', figsize=(10,5), title='Total matches win by each Team')
for i,v in enumerate(winner.values):
    plt.text(x=i, y=v+2, s=v)
    
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\text.py:1163: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# #### The conclusions from figrue:-
#    * Mumbai Indians leads the total matches won by a team.
#     <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/ipl2.jpg?raw=true' width=300 height=300 >,
#     * Chennai Super kings,KKR they are also in a race.
#     * RR and DD they are far behind

# %% [markdown]
# #### =====================================================================================================

# %% [markdown]
# # Champion in each season.

# %%
temp1_df = matches.drop_duplicates('season', keep='last')
temp1_df = temp1_df[['season', 'winner']]
temp1_df.sort_values('season',inplace=True)
temp1_df.reset_index(inplace=True, drop=True)
temp1_df
# Out:
#     season winner
# 0     2008     RR
# 1     2009     DC
# 2     2010    CSK
# 3     2011    CSK
# 4     2012    KKR
# 5     2013     MI
# 6     2014    KKR
# 7     2015     MI
# 8     2016    SRH
# 9     2017     MI
# 10    2018    CSK
# 11    2019     MI
# 12    2020     MI

# %% [markdown]
# <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/ipl2.jpg?raw=true' width=500 height=300 >,
# <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/ipl3.jpg?raw=true' width=500 height=300 >

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # Team winning Match after winning toss?

# %%
count_toss=matches['toss_winner'].value_counts()
count_winner=matches['winner'].value_counts()

# %%
count_toss
# Out:
# MI      106
# KKR      98
# CSK      97
# RCB      87
# RR       87
# KXIP     85
# DD       80
# SRH      57
# DC       53
# PWI      20
# GL       15
# RPS      13
# DCa      10
# KTK       8
# Name: toss_winner, dtype: int64

# %%
count_winner
# Out:
# MI      120
# CSK     106
# KKR      99
# RCB      91
# KXIP     88
# RR       81
# DD       67
# SRH      66
# DC       38
# RPS      15
# GL       13
# PWI      12
# DCa      10
# KTK       6
# Name: winner, dtype: int64

# %%
toss_win_match_win=matches[matches['toss_winner']==matches['winner']]
toss_win_match_win
# Out:
#           id  season        city        date team1 team2 toss_winner  \
# 1         61    2008  Chandigarh  19-04-2008   CSK  KXIP         CSK
# 8         68    2008   Hyderabad  24-04-2008    DC    RR          RR
# 10        70    2008   Bangalore  26-04-2008   RCB    RR          RR
# 12        72    2008      Mumbai  27-04-2008    MI    DC          DC
# 14        74    2008   Bangalore  28-04-2008   CSK   RCB         CSK
# ..       ...     ...         ...         ...   ...   ...         ...
# 808  1216506    2020   Abu Dhabi    11-01-20   CSK  KXIP         CSK
# 810  1216505    2020   Abu Dhabi    11-02-20    DC   RCB          DC
# 811  1216495    2020     Sharjah    11-03-20   SRH    MI         SRH
# 813  1237178    2020   Abu Dhabi    11-06-20   RCB   SRH         SRH
# 814  1237180    2020   Abu Dhabi    11-08-20    DC   SRH          DC
#
#     toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# ...

# %%
toss_win_match_win_teamlist=toss_win_match_win.winner.value_counts()
toss_win_match_win_teamlist
# Out:
# CSK     61
# MI      61
# KKR     55
# RR      44
# RCB     43
# KXIP    36
# DD      35
# SRH     29
# DC      22
# GL      10
# RPS      8
# DCa      7
# KTK      4
# PWI      3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(toss_win_match_win_teamlist.index,toss_win_match_win_teamlist)
plt.xticks(rotation=90)

plt.xlabel('Teams',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Toss Win Match Win Wise STATISTICS')
for i,v in enumerate(toss_win_match_win_teamlist.values):
    plt.text(x=i, y=v+2, s=v)

# %% [markdown]
# * Csk And MI are the teams that has won maximum number of matches after winning toss

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # Team winning Match after winning toss and choosing bat?

# %%
toss_win_match_win_bat=toss_win_match_win[toss_win_match_win["toss_decision"]=="bat"]

# %%
toss_win_match_win_bat_teamlist=toss_win_match_win_bat.winner.value_counts()
toss_win_match_win_bat_teamlist
# Out:
# CSK     31
# MI      27
# KKR     17
# RR      15
# DC      13
# DD      11
# RCB     11
# SRH     10
# KXIP     6
# PWI      3
# DCa      1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(toss_win_match_win_bat_teamlist.index,toss_win_match_win_bat_teamlist)
plt.xticks(rotation=90)

plt.xlabel('Teams',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Toss Win Match Win Decision:-Bat  STATISTICS')
# Out:
# Text(0.5, 1.0, 'Toss Win Match Win Decision:-Bat  STATISTICS')

# %% [markdown]
#    Csk has won maximum number of matches after winning toss and choosing bat.....ie... CSK loves to bat first
#     #### ====================================================================================================

# %% [markdown]
# # Team winning Match after winning toss and choosing field?

# %%
toss_win_match_win_field=toss_win_match_win[toss_win_match_win["toss_decision"]=="field"]
toss_win_match_win_field
# Out:
#           id  season       city        date team1 team2 toss_winner  \
# 8         68    2008  Hyderabad  24-04-2008    DC    RR          RR
# 10        70    2008  Bangalore  26-04-2008   RCB    RR          RR
# 12        72    2008     Mumbai  27-04-2008    MI    DC          DC
# 17        77    2008  Hyderabad  01-05-2008    DC  KXIP        KXIP
# 24        84    2008  Bangalore  05-05-2008   RCB  KXIP        KXIP
# ..       ...     ...        ...         ...   ...   ...         ...
# 807  1216502    2020    Sharjah  10-31-2020   RCB   SRH         SRH
# 808  1216506    2020  Abu Dhabi    11-01-20   CSK  KXIP         CSK
# 810  1216505    2020  Abu Dhabi    11-02-20    DC   RCB          DC
# 811  1216495    2020    Sharjah    11-03-20   SRH    MI         SRH
# 813  1237178    2020  Abu Dhabi    11-06-20   RCB   SRH         SRH
#
#     toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 8           field  normal           0     RR            0               3
# ...

# %%
toss_win_match_win_field_teamlist=toss_win_match_win_field.winner.value_counts()
toss_win_match_win_field_teamlist
# Out:
# KKR     38
# MI      34
# RCB     32
# CSK     30
# KXIP    30
# RR      29
# DD      24
# SRH     19
# GL      10
# DC       9
# RPS      8
# DCa      6
# KTK      4
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(toss_win_match_win_field_teamlist.index,toss_win_match_win_field_teamlist)
plt.xticks(rotation=90)

plt.xlabel('Teams',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Toss Win Match Win Decision:-Field     STATISTICS')
# Out:
# Text(0.5, 1.0, 'Toss Win Match Win Decision:-Field     STATISTICS')

# %% [markdown]
# Kkr has won maximum number of matches after winning toss and choosing field.....ie... CSK loves to field first
# #### ====================================================================================================

# %% [markdown]
# # Number of times each team played final and number of times they won matches

# %%
finals = matches.drop_duplicates('season', keep='last')
finals = finals[['season', 'team1', 'team2', 'winner', ]]

# %%
finals
# Out:
#      season team1 team2 winner
# 57     2008   CSK    RR     RR
# 114    2009    DC   RCB     DC
# 174    2010   CSK    MI    CSK
# 247    2011   CSK   RCB    CSK
# 321    2012   CSK   KKR    KKR
# 397    2013    MI   CSK     MI
# 457    2014  KXIP   KKR    KKR
# 516    2015    MI   CSK     MI
# 576    2016   SRH   RCB    SRH
# 635    2017    MI   RPS     MI
# 695    2018   SRH   CSK    CSK
# 755    2019    MI   CSK     MI
# 815    2020    DC    MI     MI

# %%
# Teams who reaches maximum number of finals
most_finals  =pd.concat([finals['team1'], finals['team2']])

most_finals = most_finals.value_counts().reset_index()

most_finals = pd.DataFrame(most_finals)
most_finals.columns = ['Team', 'final_count']

# %%
# Teams who won the final.
win_finals = finals['winner'].value_counts().reset_index()
win_finals = pd.DataFrame(win_finals,)

most_finals = most_finals.merge(win_finals, left_on='Team',right_on='index', how='outer')
most_finals.drop('index', axis=1,inplace=True)
most_finals.set_index('Team', drop=True, inplace=True)
most_finals.columns = ['Number of Times Finals played', 'Number of Times Finals won']
most_finals.plot(kind='bar', figsize=(13,7),fontsize=12, title='Team played in finals and their wins')
plt.show()

# %% [markdown]
# * Chennai super kings played the maximum number of times 6 in finals. (CSK rocks),
#  <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/ipl3.jpg?raw=true' width=500 height=300>,
#  And Mumbai Indians won 5 seasons, which is the maximum number of times a team won IPL

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # Top 10 players who won the maximum number of times , Man of the match title.

# %%
pom = matches['player_of_match'].value_counts()[:10]
plt.figure(facecolor='#FFDAB9')
pom.plot(kind='bar', figsize=(13,5), title='Players who won maximum number of "Man of the Match" titles')
for i,v in enumerate(pom.values):
    plt.text(x=i, y=v+0.6, s=v)

# %%
color=["violet","indigo","blue","green","yellow","orange","red"]

# %%
pom = matches['player_of_match'].value_counts()[:10]
plt.figure(facecolor='#FFDAB9')
pom.plot(kind='bar', figsize=(13,5), title='Players who won maximum number of "Man of the Match" titles',color=color)
for i,v in enumerate(pom.values):
    plt.text(x=i, y=v+0.6, s=v)

# %% [markdown]
# As expected ,AB De Villiers have maximum number of man of the match titles.
# <img src='https://github.com/anmol2806/ipl_pics_analysis/blob/main/ipl_pics/ipl4.jpg?raw=true' width=450 height=400 >
#
# * MS Dhoni have won 17 man of the match titles.
# * One important thing to notice, YK Pathan have won 16 titles as he is not in top 5 leading run scorers

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# #  Top 10 Favourite Umpires.

# %%
umpire = pd.concat([matches['umpire1'], matches['umpire2']]).value_counts()[:10]
umpire.plot(kind='bar',title='Top 10 favourite Umpires', figsize=(10,5),color=color)
for i,v in enumerate(umpire.values):
    plt.text(x=i, y=v+0.6, s=v)
plt.show()

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # Top 5 Winner team who defeated the Losser team with the highest number of run Difference.

# %%
run_diff = matches.sort_values('win_by_runs', ascending=False)[:5]
run_diff[['season', 'team1','team2', 'winner', 'win_by_runs', 'venue']].reset_index(drop=True)
# Out:
#    season team1 team2 winner  win_by_runs                  venue
# 0    2017    MI    DD     MI          146       Feroz Shah Kotla
# 1    2016   RCB    GL    RCB          144  M Chinnaswamy Stadium
# 2    2008   KKR   RCB    KKR          140  M Chinnaswamy Stadium
# 3    2015   RCB  KXIP    RCB          138  M Chinnaswamy Stadium
# 4    2013   RCB   PWI    RCB          130  M Chinnaswamy Stadium

# %% [markdown]
# * RCB defeated the rival team 3 times with big margin of runs.

# %% [markdown]
# #### ==================================================================================================

# %% [markdown]
# # Top 5 Winner team who defeated the Losser team with the highest number of wickets in their hand.

# %%
wicket_max = matches.sort_values('win_by_wickets', ascending=False)[:5]
wicket_max[['season', 'team1','team2', 'winner', 'win_by_wickets', 'venue']].reset_index(drop=True)
# Out:
#    season team1 team2 winner  win_by_wickets  \
# 0    2020  KXIP   CSK    CSK              10
# 1    2015    DD   RCB    RCB              10
# 2    2016    GL   SRH    SRH              10
# 3    2020   CSK    MI     MI              10
# 4    2009  KXIP    DD     DD              10
#
#                                     venue
# 0     Dubai International Cricket Stadium
# 1                        Feroz Shah Kotla
# 2  Saurashtra Cricket Association Stadium
# 3                 Sharjah Cricket Stadium
# 4                                Newlands

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# # TOSS ANALYSIS

# %% [markdown]
# ## Toss decision whether Captain choose bat or ball.

# %%
toss_decision = matches['toss_decision'].value_counts()
plt.figure(figsize=(10,5))
plt.pie(labels=toss_decision.index, x=toss_decision.values, explode=[0.1,0], autopct='%.f%%',
        shadow=True,startangle=90, textprops={'fontsize':15})
plt.show()

# %% [markdown]
# * 61% Captains choose to field first.
# * I think they love to chase a target.

# %% [markdown]
# #### ====================================================================================================

# %% [markdown]
# ## Total Toss won by each team and total matches played by them.

# %%
toss_team = pd.concat([matches['team1'], matches['team2']]).value_counts().reset_index()
toss_team = pd.DataFrame(toss_team)
toss_team.columns = ['Team', 'Total Matches Played']

toss_winner = matches['toss_winner'].value_counts().reset_index()
toss_winner = pd.DataFrame(toss_winner)

# merging to DataFrame.
toss_team = toss_team.merge(toss_winner, how='outer', left_on='Team', right_on='index')
toss_team.drop('index', axis=1, inplace=True)
toss_team.columns = ['Team', 'Total Matches Played', 'Total Toss win']

toss_team.set_index('Team', inplace=True)
toss_team.plot(kind='bar', title="""Total Matches Played by each Team and their Toss Win""", figsize=(13,6))
plt.show()

# %% [markdown]
# #### ====================================================================================================
