# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
mat = pd.read_csv('matches_2008_to_2019.csv')

# %%
mat.head(4)
# Out:
#    id    Season       city        date                   team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017     Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017          Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017           Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017  Rising Pune Supergiant
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# ...

# %%
#data cleaning
mat.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
mat=mat.drop(columns=['umpire3'], axis=1)

# %%
mat["season"]=mat["Season"].str.replace("IPL-","")

# %%
a=mat["season"].value_counts().index.sort_values()

# %%
b=[]

# %%
def replaceEven (a): 
    for i in range(1, 12): 
        b.append(a[i].replace(a[i],str(i)))
        
replaceEven(a)

# %%
mat["winner_short"]=mat["winner"].replace(['Kings XI Punjab', 'Royal Challengers Bangalore'], 
                     ["KXIP", "RCb"]) 
mat

# %% [markdown]
# # Q1 Matches played in Season wise
# # Q2 Matches Player on different venues for 10
# # Q3 Team winning Match after winning toss
# # Q4 Team winning Match after winning toss and choosing bat
# # Q5 Team winning Match after winning toss and choosing field
# # Q6 Top 5 wins by most runs
# # Q7 Top 5 wins by most wickets
# # Q8 Top 5 players to win most player of matches
# # Q9 Most matches by umpires

# %% [markdown]
# # Answer 1

# %%
count_match_seasonwise=mat["Season"].value_counts()
count_match_seasonwise
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2016    60
# IPL-2018    60
# IPL-2014    60
# IPL-2019    60
# IPL-2010    60
# IPL-2015    59
# IPL-2017    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
c=mat["Season"].value_counts().index.tolist()
c
# Out:
# ['IPL-2013',
#  'IPL-2012',
#  'IPL-2011',
#  'IPL-2016',
#  'IPL-2018',
#  'IPL-2014',
#  'IPL-2019',
#  'IPL-2010',
#  'IPL-2015',
#  'IPL-2017',
#  'IPL-2008',
#  'IPL-2009']

# %%
plt.figure(figsize=(10,5))
plt.bar(c,count_match_seasonwise)
plt.xticks(rotation=90)

plt.xlabel('Season',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Season Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Season Wise STATISTICS')

# %%
plt.figure(figsize=(10,5))
plt.plot(c,count_match_seasonwise)


plt.xlabel('Season',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Season Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Season Wise STATISTICS')

# %% [markdown]
# # Answer 2

# %%
count_match_venues=mat["venue"].value_counts().head(10)
count_match_venues
# Out:
# Eden Gardens                                  77
# M Chinnaswamy Stadium                         73
# Wankhede Stadium                              73
# Feroz Shah Kotla                              67
# Rajiv Gandhi International Stadium, Uppal     56
# MA Chidambaram Stadium, Chepauk               49
# Sawai Mansingh Stadium                        47
# Punjab Cricket Association Stadium, Mohali    35
# Maharashtra Cricket Association Stadium       21
# Dr DY Patil Sports Academy                    17
# Name: venue, dtype: int64

# %%
len(mat["venue"].value_counts())
# Out:
# 41

# %%
mat["venue"].value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Brabourne Stadium                                       11
# ...

# %%
d=mat["venue"].value_counts().head(10).index.tolist()

# %%
plt.figure(figsize=(10,5))
plt.bar(d,count_match_venues)
plt.xticks(rotation=90)

plt.xlabel('Venue',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Venue Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Venue Wise STATISTICS')

# %%
plt.figure(figsize=(10,5))
plt.plot(d,count_match_venues)
plt.xticks(rotation=90)


plt.xlabel('Season',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Venue Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Venue Wise STATISTICS')

# %% [markdown]
# # Answer 3

# %%
count_toss=mat['toss_winner'].value_counts()
count_winner=mat['winner'].value_counts()

# %%
count_toss
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
count_winner
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
win_count = 0
for index, value in mat.iterrows():
    if(value['toss_winner']==value['winner']):
#         print(value['winner'])
        win_count += 1

print(f'The number of times the team winning toss have won: {win_count}')
print(len(mat))
prob = win_count/len(mat)
print('The probability of winning if won the toss: {:.2f}' .format(prob))
# Out:
# The number of times the team winning toss have won: 393
# 756
# The probability of winning if won the toss: 0.52

# %%
toss_win_match_win=mat[mat['toss_winner']==mat['winner']]
toss_win_match_win
# Out:
#         id    Season           city        date                        team1  \
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        6  IPL-2017      Hyderabad  09-04-2017                Gujarat Lions
# ..     ...       ...            ...         ...                          ...
# 750  11346  IPL-2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
twmw_teamwise=toss_win_match_win.winner.value_counts()
twmw_teamwise
# Out:
# Chennai Super Kings            57
# Mumbai Indians                 56
# Kolkata Knight Riders          53
# Rajasthan Royals               42
# Royal Challengers Bangalore    41
# Delhi Daredevils               35
# Kings XI Punjab                35
# Sunrisers Hyderabad            23
# Deccan Chargers                19
# Gujarat Lions                  10
# Delhi Capitals                  7
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Pune Warriors                   3
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(twmw_teamwise.index,twmw_teamwise)
plt.xticks(rotation=90)

plt.xlabel('Teams',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Toss win Match Win Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Toss win Match Win Wise STATISTICS')

# %% [markdown]
# # Answer 4

# %%
toss_win_match_win_bat=toss_win_match_win[toss_win_match_win["toss_decision"]=="bat"]

# %%
toss_win_match_win_bat
# Out:
#         id    Season       city        date                        team1  \
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# 20      21  IPL-2017  Hyderabad  19-04-2017          Sunrisers Hyderabad
# 50      51  IPL-2017      Delhi  12-05-2017             Delhi Daredevils
# 54      55  IPL-2017      Delhi  14-05-2017  Royal Challengers Bangalore
# ..     ...       ...        ...         ...                          ...
# 713  11309  IPL-2019    Chennai  06-04-2019          Chennai Super Kings
# 729  11325  IPL-2019      Delhi  18-04-2019               Mumbai Indians
# 741  11337  IPL-2019      Delhi  28-04-2019               Delhi Capitals
# 746  11342  IPL-2019     Mumbai  02-05-2019               Mumbai Indians
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
twmwb_teamwise=toss_win_match_win_bat.winner.value_counts()
twmwb_teamwise
# Out:
# Chennai Super Kings            30
# Mumbai Indians                 25
# Rajasthan Royals               15
# Kolkata Knight Riders          15
# Delhi Daredevils               11
# Deccan Chargers                11
# Royal Challengers Bangalore     9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 6
# Pune Warriors                   3
# Delhi Capitals                  1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(twmwb_teamwise.index,twmwb_teamwise)
plt.xticks(rotation=90)

plt.xlabel('Teams',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Toss win Match win decision-bat    Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Toss win Match win decision-bat    Wise STATISTICS')

# %% [markdown]
# # Answer 5

# %%
toss_win_match_win_field=toss_win_match_win[toss_win_match_win["toss_decision"]=="field"]

# %%
twmwf_teamwise=toss_win_match_win_field.winner.value_counts()
twmwf_teamwise
# Out:
# Kolkata Knight Riders          38
# Royal Challengers Bangalore    32
# Mumbai Indians                 31
# Kings XI Punjab                29
# Rajasthan Royals               27
# Chennai Super Kings            27
# Delhi Daredevils               24
# Sunrisers Hyderabad            15
# Gujarat Lions                  10
# Deccan Chargers                 8
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(twmwf_teamwise.index,twmwf_teamwise)
plt.xticks(rotation=90)

plt.xlabel('Teams',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Toss win Match Win decision-field    Wise STATISTICS')
# Out:
# Text(0.5, 1.0, 'Toss win Match Win decision-field    Wise STATISTICS')

# %% [markdown]
# # Answer 6

# %%
most_runs=mat.sort_values("win_by_runs")[-1:-6:-1]
most_runs
# Out:
#       id    Season       city        date                        team1  \
# 43    44  IPL-2017      Delhi  06-05-2017               Mumbai Indians
# 619  620  IPL-2016  Bangalore  14-05-2016  Royal Challengers Bangalore
# 59    60  IPL-2008  Bangalore  18-04-2008        Kolkata Knight Riders
# 556  557  IPL-2015  Bangalore  06-05-2015  Royal Challengers Bangalore
# 410  411  IPL-2013  Bangalore  23-04-2013  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# 619                Gujarat Lions                Gujarat Lions         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 556              Kings XI Punjab              Kings XI Punjab         field
# 410                Pune Warriors                Pune Warriors         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Answer 7

# %%
most_wicket=mat.sort_values(["win_by_wickets","Season"])[-1:-6:-1]
most_wicket
# Out:
#        id    Season        city        date             team1  \
# 683  7941  IPL-2018      Indore  14-05-2018   Kings XI Punjab
# 34     35  IPL-2017  Chandigarh  30-04-2017  Delhi Daredevils
# 2       3  IPL-2017      Rajkot  07-04-2017     Gujarat Lions
# 590   591  IPL-2016      Rajkot  21-04-2016     Gujarat Lions
# 542   543  IPL-2015       Delhi  26-04-2015  Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 683  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 34               Kings XI Punjab              Kings XI Punjab         field
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# 590          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 542  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
mw=mat[mat["win_by_wickets"]==10]
mw.sort_values("Season")[-1:-6:-1]
# Out:
#        id    Season        city        date             team1  \
# 683  7941  IPL-2018      Indore  14-05-2018   Kings XI Punjab
# 34     35  IPL-2017  Chandigarh  30-04-2017  Delhi Daredevils
# 2       3  IPL-2017      Rajkot  07-04-2017     Gujarat Lions
# 590   591  IPL-2016      Rajkot  21-04-2016     Gujarat Lions
# 542   543  IPL-2015       Delhi  26-04-2015  Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 683  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 34               Kings XI Punjab              Kings XI Punjab         field
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# 590          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 542  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Answer 8

# %%
mvps=mat['player_of_match'].value_counts().head(5)
mvps1=mat['player_of_match'].value_counts().head(5).index.tolist()
mvps2=mvps=mat['player_of_match'].value_counts().head(5).values.tolist()
plt.bar(mvps1,mvps2)
plt.xlabel('Player',fontsize=13)
plt.ylabel('No.of matches',labelpad=15,fontsize=13)
plt.title('Most Player of Matches Award')
# Out:
# Text(0.5, 1.0, 'Most Player of Matches Award')

# %% [markdown]
# # Answer 9

# %%
umpire1_ser = mat['umpire1'].value_counts()
umpire2_ser = mat['umpire2'].value_counts()

# %%
umpires=pd.concat([umpire1_ser,umpire2_ser],axis=1)

# %%
umpires
# Out:
#                       umpire1  umpire2
# HDPK Dharmasena          73.0     14.0
# Asad Rauf                51.0      NaN
# S Ravi                   49.0     57.0
# AK Chaudhary             43.0     15.0
# Aleem Dar                38.0      NaN
# ...                       ...      ...
# K Srinivasan              NaN      3.0
# KN Anantapadmanabhan      NaN      3.0
# SD Ranade                 NaN      2.0
# Nand Kishore              NaN      1.0
# Subroto Das               NaN      1.0
#
# [75 rows x 2 columns]

# %%
umpire_ser = umpires.sum(axis=1)
print(umpire_ser)
umpire_df = pd.DataFrame(columns=["umpire", "matches"])

for items in umpire_ser.iteritems():
    temp_df4 = pd.DataFrame({
        'umpire':[items[0]],
        'matches':[items[1]]
    })
    umpire_df= umpire_df.append(temp_df4, ignore_index=True)
# Out:
# HDPK Dharmasena          87.0
# Asad Rauf                51.0
# S Ravi                  106.0
# AK Chaudhary             58.0
# Aleem Dar                38.0
#                         ...
# K Srinivasan              3.0
# KN Anantapadmanabhan      3.0
# SD Ranade                 2.0
# Nand Kishore              1.0
# Subroto Das               1.0
# Length: 75, dtype: float64

# %%
umpire_df.sort_values('matches', ascending=False).head()
# Out:
#              umpire  matches
# 2            S Ravi    106.0
# 0   HDPK Dharmasena     87.0
# 12    C Shamshuddin     73.0
# 3      AK Chaudhary     58.0
# 60       SJA Taufel     55.0

# %%
#season wise team winnings
teams_per_season =mat.groupby('season')['winner'].value_counts()
teams_per_season
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#                                        ..
# 2017    Sunrisers Hyderabad             8
#         Kings XI Punjab                 7
#         Delhi Daredevils                6
#         Gujarat Lions                   4
#         Royal Challengers Bangalore     3
# Name: winner, Length: 84, dtype: int64

# %%
import seaborn as sns
plt.title("IPL Venues")
sns.barplot(x='matches', y='venue', data=venue_df);

# %%
venue_df
# Out:
#                                         venue matches
# 0                       M Chinnaswamy Stadium      66
# 1                                Eden Gardens      61
# 2                            Feroz Shah Kotla      60
# 3                            Wankhede Stadium      57
# 4   Rajiv Gandhi International Stadium, Uppal      49
# 5             MA Chidambaram Stadium, Chepauk      48
# 6  Punjab Cricket Association Stadium, Mohali      35
# 7                      Sawai Mansingh Stadium      33
# 8                  Dr DY Patil Sports Academy      17
# 9                  Subrata Roy Sahara Stadium      17

# %%
mat['player_of_match'].value_counts().head(10)
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# G Gambhir         13
# MS Dhoni          13
# AM Rahane         12
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
win_count = 0
for index, value in mat.iterrows():
    if(value['toss_winner']==value['winner']):
#         print(value['winner'])
        win_count += 1

print(f'The number of times the team winning toss have won: {win_count}')
print(len(mat))
prob = win_count/len(mat)
print('The probability of winning if won the toss: {:.2f}' .format(prob))
# Out:
# The number of times the team winning toss have won: 325
# 636
# The probability of winning if won the toss: 0.51

# %%
defend_vict_ser = mat['win_by_runs'].value_counts()
defend_vict_ser.sort_values(ascending=True)
# Out:
# 42       1
# 146      1
# 36       1
# 40       1
# 140      1
#       ...
# 10       9
# 7        9
# 23       9
# 9        9
# 0      349
# Name: win_by_runs, Length: 86, dtype: int64

# %%
score = 146
for index, row in mat.iterrows():
    if(row['win_by_runs'] == score):
        print(row)
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# Name: 43, dtype: object

# %%
mat.head(5)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
mat["season"]
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 631    2016
# 632    2016
# 633    2016
# 634    2016
# 635    2016
# Name: season, Length: 636, dtype: int64

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from tkinter import * 
from matplotlib.figure import Figure 
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,  
NavigationToolbar2Tk)

# %%
mat1 = pd.read_csv('IPLL/matches.csv')
#counting toss win and match win for each team
# Out:
# TOSSES WIN
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64
# MATCHES WIN
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# ...

# %%
count_toss=mat1['toss_winner'].value_counts()
count_winner=mat1['winner'].value_counts()
print('TOSSES WIN')
print(count_toss)
print('MATCHES WIN')
print(count_winner)
teams_toss=mat1['toss_winner'].value_counts().index.tolist()
teams_winner=mat1['winner'].value_counts().index.tolist()
# Out:
# TOSSES WIN
# MI      85
# KKR     78
# DD      72
# RCB     70
# KXIP    68
# CSK     66
# RR      63
# DC      43
# SRH     35
# PWI     20
# GL      15
# RPS     13
# KTK      8
# Name: toss_winner, dtype: int64
# MATCHES WIN
# MI      92
# CSK     79
# KKR     77
# RCB     73
# KXIP    70
# RR      63
# DD      62
# SRH     42
# DC      29
# RPS     15
# GL      13
# PWI     12
# KTK      6
# Name: winner, dtype: int64

# %%
a=mat1['toss_winner'].value_counts().index.tolist()
b=["MI","KKR","DD","RCB","KXIP","CSK","RR","DC","SRH","PWI","GL","KTK","RPS","RPS"]

# %%
mat1=mat1.replace(a,b)

# %%
def plot1(): 
       
    # the figure that will contain the plot 
    fig = Figure(figsize = (10, 5),  dpi = 100) 
    
    plot1 = fig.add_subplot(111)
    
    plot1.bar(teams_toss,count_toss)
    
    plot1.set(xlabel="Toss Winner", ylabel="No of matches",title="Season wise match stats" )
    
    fig.legend(b)
    # creating the Tkinter canvas 
    # containing the Matplotlib figure 
    canvas = FigureCanvasTkAgg(fig,master = window)   
    canvas.draw() 
  
    # placing the canvas on the Tkinter window 
    canvas.get_tk_widget().pack() 
  
    # creating the Matplotlib toolbar 
    toolbar = NavigationToolbar2Tk(canvas, window) 
    toolbar.update() 
  
    # placing the toolbar on the Tkinter window 
    canvas.get_tk_widget().pack()

# %%
# for two graphs together
def plot2(): 
       
    # the figure that will contain the plot 
    fig = Figure(figsize = (10, 5), dpi = 100) 
    
    plot2 = fig.add_subplot(111)
    
    plot2.plot(teams_toss,count_toss,'r-',marker='o')
        
    plot1 = fig.add_subplot(211)
    
    plot1.bar(teams_toss,count_toss)
    
    # creating the Tkinter canvas 
    # containing the Matplotlib figure 
    canvas = FigureCanvasTkAgg(fig,master = window)   
    canvas.draw() 
  
    # placing the canvas on the Tkinter window 
    canvas.get_tk_widget().pack() 
  
    # creating the Matplotlib toolbar 
    toolbar = NavigationToolbar2Tk(canvas, window) 
    toolbar.update() 
  
    # placing the toolbar on the Tkinter window 
    canvas.get_tk_widget().pack()
# Out:
# Object `fig.add_subplot` not found.

# %%
        
def season_wise_stats():

        fig = Figure(figsize = (10, 5),  dpi = 100) 

        plot2 = fig.add_subplot(111)

        plot2.bar(c,count_match_seasonwise)

        plot2.set(xlabel="Seasons", ylabel="No of matches",title="Season wise match stats" )

        # creating the Tkinter canvas 
        canvas = FigureCanvasTkAgg(fig,master = window)   
        canvas.draw() 

        # placing the canvas on the Tkinter window 
        canvas.get_tk_widget().pack() 

        # creating the Matplotlib toolbar 
        toolbar = NavigationToolbar2Tk(canvas, window) 
        toolbar.update() 

        # placing the toolbar on the Tkinter window 
        canvas.get_tk_widget().pack()

# %%
def Toss_win_Match_win():
    
    fig = Figure(figsize = (10, 5),  dpi = 100) 
    
    plt = fig.add_subplot(111)
    
    plt.bar(twmwb_teamwise.index,twmwb_teamwise)
    
    plt.set(xlabel="Teams", ylabel="No of matches",title="Toss win Match win decision-bat    Wise STATISTICS" )
    
    # creating the Tkinter canvas 
    # containing the Matplotlib figure 
    canvas = FigureCanvasTkAgg(fig,master = window)   
    canvas.draw() 
  
    # placing the canvas on the Tkinter window 
    canvas.get_tk_widget().pack() 
  
    # creating the Matplotlib toolbar 
    toolbar = NavigationToolbar2Tk(canvas, window) 
    toolbar.update() 
  
    # placing the toolbar on the Tkinter window 
    canvas.get_tk_widget().pack()

# %%
# the main Tkinter window 
window = Tk() 
  
# setting the title  
window.title('Plotting in Tkinter') 
  
# dimensions of the main window 
window.geometry("500x500") 

# bg = PhotoImage(file = "histogram.png")

# Create Canvas 
# canvas1 = Canvas( window, width = 400,  height = 400) 
  
# canvas1.pack(fill = "both", expand = True) 
  
# # Display image 
# canvas1.create_image( 0, 0, image = bg,  anchor = "nw") 


# window.configure(bg='blue')

# button that displays the plot 
plot_button = Button(master = window,  command = plot1,  height = 2,   width = 50, text = "Plot for match winning stats",
                      bg='black', fg='white'  ) 

plot_button2 = Button(master = window, command = season_wise_stats,  height = 2,   width = 50, text = "Season wise match stats",
                      bg='black', fg='white'  ) 
plot_button3 = Button(master = window, command = Toss_win_Match_win,  height = 2,   width = 50, text = "Toss wise match win",
                      bg='black', fg='white'  ) 

button = Button(window,text = 'Graphs',command = showMsg)  

button1 = Button(window, text = 'Submit',command = changeText)  
 
button1.pack()   

button.pack()      
  
# place the button  
# in main window 
plot_button.pack() 
plot_button2.pack() 
plot_button3.pack()
# run the gui 
window.mainloop()

# %%
print(type(mat["date"][2]))
# Out:
# <class 'str'>

# %%
mat.dtypes
# Out:
# id                  int64
# Season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# dtype: object

# %%
mat["Date"]=pd.to_datetime(mat["date"])
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
mat.sort_values(["Date"])
# Out:
#         id    Season           city        date                        team1  \
# 76      77  IPL-2008      Hyderabad  01-05-2008              Deccan Chargers
# 77      78  IPL-2008         Jaipur  01-05-2008             Rajasthan Royals
# 116    117  IPL-2008         Mumbai  01-06-2008          Chennai Super Kings
# 78      79  IPL-2008        Chennai  02-05-2008          Chennai Super Kings
# 110    111  IPL-2008      Bangalore  03-05-2008  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 719  11315  IPL-2019         Mumbai  10-04-2019              Kings XI Punjab
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 720  11316  IPL-2019         Jaipur  11-04-2019             Rajasthan Royals
# 721  11317  IPL-2019        Kolkata  12-04-2019        Kolkata Knight Riders
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
mat["year"]=mat["Date"].dt.year
mat["month"]=mat["Date"].dt.month
mat["day"]=mat["Date"].dt.day

# %%
mat.sort_values(["Season","date"])
# Out:
#         id    Season        city        date                        team1  \
# 76      77  IPL-2008   Hyderabad  01-05-2008              Deccan Chargers
# 77      78  IPL-2008      Jaipur  01-05-2008             Rajasthan Royals
# 116    117  IPL-2008      Mumbai  01-06-2008          Chennai Super Kings
# 78      79  IPL-2008     Chennai  02-05-2008          Chennai Super Kings
# 80      81  IPL-2008  Chandigarh  03-05-2008              Kings XI Punjab
# ..     ...       ...         ...         ...                          ...
# 704  11145  IPL-2019      Mohali  30-03-2019               Mumbai Indians
# 705  11146  IPL-2019       Delhi  30-03-2019        Kolkata Knight Riders
# 744  11340  IPL-2019   Bengaluru  30-04-2019  Royal Challengers Bangalore
# 706  11147  IPL-2019   Hyderabad  31-03-2019          Sunrisers Hyderabad
# 707  11148  IPL-2019     Chennai  31-03-2019          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mat
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...
